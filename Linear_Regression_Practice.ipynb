# %% [markdown]
# <a href="https://colab.research.google.com/github/atletlgomez/Linear-Regression-Practice-/blob/main/Linear_Regression_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm


# Suppress warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://openintro.org/data/csv/bac.csv"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers)
response.raise_for_status() # Raise an exception for bad status codes
df = pd.read_csv(StringIO(response.text))

# %% [markdown]
# ###Beer and Blood Alcohol Content

# %% [markdown]
# Quick Disc.
#
# 16 Students volunteers drank a randomly assigned number of cans of beer

# %%
df.head()
# Out:
#    student  beers   bac
# 0        1      5  0.10
# 1        2      2  0.03
# 2        3      9  0.19
# 3        4      8  0.12
# 4        5      3  0.04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   student  16 non-null     int64
#  1   beers    16 non-null     int64
#  2   bac      16 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 516.0 bytes

# %%
fig1 = px.scatter(df, x='beers', y='bac')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# slope and the intercept

# %%
m, b = np.polyfit(df['beers'], df['bac'], 1)

# %%
print(m, b)
# Out:
# 0.01796376186367558 -0.012700603968938752

# %% [markdown]
# returns the slope and the intercept

# %%
line = np.linspace(df.beers.min(), df.beers.max(), 100)

# %% [markdown]
# a line is created with the smallest and greatest values with 100 points in between

# %%
import plotly.graph_objects as go

fig = px.scatter(df, x='beers', y='bac',
                 title='BAC vs. Number of Beers with Fit Line')
fig.add_trace(go.Scatter(x=line, y=y, mode='lines', name='Fit Line'))
fig.update_layout(xaxis_title='Number of Beers',
                  yaxis_title='Blood Alcohol Content (BAC)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["bac_pred"] = m * df["beers"] + b

# %%
df.head()
# Out:
#    student  beers   bac  bac_pred
# 0        1      5  0.10  0.077118
# 1        2      2  0.03  0.023227
# 2        3      9  0.19  0.148973
# 3        4      8  0.12  0.131009
# 4        5      3  0.04  0.041191

# %% [markdown]
# Blood Alochol Level was close to the actual BAC(Y)

# %%
df['bac'].corr(df['bac_pred'])
# Out:
# np.float64(0.8943381479304818)

# %% [markdown]
# at 0.89 the relationship is strong, slope is positive heading in a upward direction

# %% [markdown]
# data is close to one in this dataset which mean it is close to the predicted line

# %%
X = sm.add_constant(df['beers'])
model = sm.OLS(df["bac"], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    bac   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     55.94
# Date:                Fri, 25 Jul 2025   Prob (F-statistic):           2.97e-06
# Time:                        03:16:03   Log-Likelihood:                 40.609
# No. Observations:                  16   AIC:                            -77.22
# Df Residuals:                      14   BIC:                            -75.67
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0127      0.013     -1.005      0.332      -0.040       0.014
# ...

# %% [markdown]
# ###North Carolina Births

# %% [markdown]
# random sample of 150 briths
#
# 50 were from mothers who smoked and 100 that dont

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://openintro.org/data/csv/births.csv"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers)
response.raise_for_status() # Raise an exception for bad status codes
df2 = pd.read_csv(StringIO(response.text))

# %%
df2.head()
# Out:
#    f_age  m_age  weeks  premature  visits  gained  weight sex_baby      smoke
# 0   31.0     30     39  full term    13.0     1.0    6.88     male     smoker
# 1   34.0     36     39  full term     5.0    35.0    7.69     male  nonsmoker
# 2   36.0     35     40  full term    12.0    29.0    8.88     male  nonsmoker
# 3   41.0     40     40  full term    13.0    30.0    9.00   female  nonsmoker
# 4   42.0     37     40  full term     NaN    10.0    7.94     male  nonsmoker

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   f_age      119 non-null    float64
#  1   m_age      150 non-null    int64
#  2   weeks      150 non-null    int64
#  3   premature  150 non-null    object
#  4   visits     149 non-null    float64
#  5   gained     148 non-null    float64
#  6   weight     150 non-null    float64
#  7   sex_baby   150 non-null    object
#  8   smoke      150 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 10.7+ KB

# %% [markdown]
# divide the data from smokers and non smokers and see how the baby's weight changes

# %% [markdown]
# ###Smokers Only

# %%
smokers_only = df2[df2['smoke'] == "smoker"]

# %%
smokers_only = smokers_only.reset_index(drop=True)

# %%
smokers_only.head()
# Out:
#    f_age  m_age  weeks  premature  visits  gained  weight sex_baby   smoke
# 0   31.0     30     39  full term    13.0     1.0    6.88     male  smoker
# 1   37.0     28     40  full term    12.0    35.0    8.25     male  smoker
# 2   28.0     21     35     premie     9.0    15.0    5.50   female  smoker
# 3   22.0     20     32     premie     5.0    40.0    2.69     male  smoker
# 4   25.0     19     41  full term    13.0    47.0    8.38     male  smoker

# %%
fig3 = px.scatter(smokers_only, x='weight', y='weeks')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
m2, b2 = np.polyfit(smokers_only.weeks, smokers_only.weight, 1)

# %%
print(m2, b2)
# Out:
# 0.508834279746753 -12.831473141439858

# %%
smokers_line = np.linspace(smokers_only.weeks.min(), smokers_only.weeks.max(), 100)

# %%
y2 = m2 * smokers_line + b2

# %%
fig2 = px.scatter(smokers_only, x='weeks', y='weight',
                 title='Weight vs Weeks with fitted line')
fig2.add_trace(go.Scatter(x=smokers_line, y=y2, mode='lines', name='Fit Line'))
fig2.update_layout(xaxis_title='Weekst',
                  yaxis_title='Weight')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
smokers_only["s_weight_pred"] = m2 * smokers_only["weeks"] + b2

# %%
smokers_only.head()
# Out:
#    f_age  m_age  weeks  premature  visits  gained  weight sex_baby   smoke  \
# 0   31.0     30     39  full term    13.0     1.0    6.88     male  smoker
# 1   37.0     28     40  full term    12.0    35.0    8.25     male  smoker
# 2   28.0     21     35     premie     9.0    15.0    5.50   female  smoker
# 3   22.0     20     32     premie     5.0    40.0    2.69     male  smoker
# 4   25.0     19     41  full term    13.0    47.0    8.38     male  smoker
#
#    s_weight_pred
# 0       7.013064
# 1       7.521898
# 2       4.977727
# 3       3.451224
# 4       8.030732

# %%
smokers_only['weight'].corr(smokers_only['s_weight_pred'])
# Out:
# np.float64(0.7965609824280833)

# %% [markdown]
# 0.79 the relationship is not as strong as I thought, positive but data points are far-ish from the line

# %%
X = sm.add_constant(smokers_only['weeks'])
model = sm.OLS(smokers_only["weight"], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 weight   R-squared:                       0.635
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     83.33
# Date:                Fri, 25 Jul 2025   Prob (F-statistic):           4.59e-12
# Time:                        03:42:42   Log-Likelihood:                -68.698
# No. Observations:                  50   AIC:                             141.4
# Df Residuals:                      48   BIC:                             145.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -12.8315      2.153     -5.961      0.000     -17.160      -8.503
# ...

# %% [markdown]
# ###Both graphed

# %% [markdown]
# ###Non Smokers Only

# %%
non_smokers = df2[df2['smoke'] == "nonsmoker"]

# %%
non_smokers = non_smokers.reset_index(drop=True)

# %%
m3, b3 = np.polyfit(non_smokers.weeks, non_smokers.weight, 1)

# %%
print(m3, b3)
# Out:
# 0.3212916030534353 -5.206291297709923

# %%
non_smokers.head()
# Out:
#    f_age  m_age  weeks  premature  visits  gained  weight sex_baby      smoke
# 0   34.0     36     39  full term     5.0    35.0    7.69     male  nonsmoker
# 1   36.0     35     40  full term    12.0    29.0    8.88     male  nonsmoker
# 2   41.0     40     40  full term    13.0    30.0    9.00   female  nonsmoker
# 3   42.0     37     40  full term     NaN    10.0    7.94     male  nonsmoker
# 4   35.0     35     28     premie     6.0    29.0    1.63   female  nonsmoker

# %%
global_line = np.linspace(df2.weeks.min(), df2.weeks.max(), 100)

# %%
smokers_line = m_and_b2[0] * global_line + m_and_b2[1]
nonsmokers_line = m_and_b3[0] * global_line + m_and_b3[1]

# %%
non_smokers.head()
# Out:
#    f_age  m_age  weeks  premature  visits  gained  weight sex_baby      smoke
# 0   34.0     36     39  full term     5.0    35.0    7.69     male  nonsmoker
# 1   36.0     35     40  full term    12.0    29.0    8.88     male  nonsmoker
# 2   41.0     40     40  full term    13.0    30.0    9.00   female  nonsmoker
# 3   42.0     37     40  full term     NaN    10.0    7.94     male  nonsmoker
# 4   35.0     35     28     premie     6.0    29.0    1.63   female  nonsmoker

# %% [markdown]
# ###Smokers and Non Smokers

# %%
fig3 = px.scatter(df2, x='weeks', y='weight',
                 title='weeks vs weight')
fig3.add_trace(go.Scatter(x=global_line, y=smokers_line,
                          mode='lines', name='Fit Line'))
fig3.add_trace(go.Scatter(x=global_line, y=nonsmokers_line,
                          mode='lines', name='Fit Line'))
fig3.update_layout(xaxis_title='weeks into preg.',
                  yaxis_title='weight of baby')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Babies start off underweight if their mother was a smoker
# Babies
#
# Between the  37.5 and 40 week mark, lines start to overlap due to later delivery

# %% [markdown]
# end.
